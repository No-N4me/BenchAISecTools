# %% [markdown]
# # Install dependencies

# %%
# !pip install datasets
# !pip install faker==26.0.0
# !pip install llm-guard
# !pip install guardrails-ai
# !pip install --upgrade torch torchvision transformers
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from datasets) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting faker==26.0.0
#   Using cached Faker-26.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.11/site-packages (from faker==26.0.0) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.4->faker==26.0.0) (1.16.0)
# Using cached Faker-26.0.0-py3-none-any.whl (1.8 MB)
# Installing collected packages: faker
#   Attempting uninstall: faker
#     Found existing installation: Faker 25.9.2
#     Uninstalling Faker-25.9.2:
#       Successfully uninstalled Faker-25.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# guardrails-ai 0.6.2 requires faker<26.0.0,>=25.2.0, but you have faker 26.0.0 which is incompatible.
# Successfully installed faker-26.0.0
# Requirement already satisfied: llm-guard in /opt/conda/lib/python3.11/site-packages (0.3.15)
# Requirement already satisfied: bc-detect-secrets==1.5.15 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (1.5.15)
# Requirement already satisfied: faker<28,>=26.0.0 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (26.0.0)
# Requirement already satisfied: fuzzysearch<0.9,>=0.7 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (0.7.3)
# Requirement already satisfied: json-repair<0.29,>=0.25.2 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (0.28.4)
# Requirement already satisfied: nltk<4,>=3.9.1 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (3.9.1)
# Requirement already satisfied: presidio-analyzer==2.2.354 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (2.2.354)
# Requirement already satisfied: presidio-anonymizer==2.2.354 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (2.2.354)
# Requirement already satisfied: regex==2024.7.24 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (2024.7.24)
# Requirement already satisfied: tiktoken<0.8,>=0.5 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (0.7.0)
# Requirement already satisfied: torch>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (2.6.0)
# Requirement already satisfied: transformers>=4.43.4 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (4.49.0)
# Requirement already satisfied: structlog>=24 in /opt/conda/lib/python3.11/site-packages (from llm-guard) (25.1.0)
# Requirement already satisfied: oldest-supported-numpy in /opt/conda/lib/python3.11/site-packages (from llm-guard) (2022.5.28)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from bc-detect-secrets==1.5.15->llm-guard) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from bc-detect-secrets==1.5.15->llm-guard) (2.32.3)
# Requirement already satisfied: unidiff in /opt/conda/lib/python3.11/site-packages (from bc-detect-secrets==1.5.15->llm-guard) (0.7.5)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /opt/conda/lib/python3.11/site-packages (from presidio-analyzer==2.2.354->llm-guard) (3.8.4)
# Requirement already satisfied: tldextract in /opt/conda/lib/python3.11/site-packages (from presidio-analyzer==2.2.354->llm-guard) (5.1.3)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in /opt/conda/lib/python3.11/site-packages (from presidio-analyzer==2.2.354->llm-guard) (8.13.53)
# Requirement already satisfied: pycryptodome>=3.10.1 in /opt/conda/lib/python3.11/site-packages (from presidio-anonymizer==2.2.354->llm-guard) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.11/site-packages (from faker<28,>=26.0.0->llm-guard) (2.9.0)
# Requirement already satisfied: attrs>=19.3 in /opt/conda/lib/python3.11/site-packages (from fuzzysearch<0.9,>=0.7->llm-guard) (23.2.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4,>=3.9.1->llm-guard) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4,>=3.9.1->llm-guard) (1.4.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from nltk<4,>=3.9.1->llm-guard) (4.67.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->llm-guard) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.4.0->llm-guard) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.43.4->llm-guard) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.43.4->llm-guard) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.43.4->llm-guard) (24.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.43.4->llm-guard) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.43.4->llm-guard) (0.5.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.4->faker<28,>=26.0.0->llm-guard) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->bc-detect-secrets==1.5.15->llm-guard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->bc-detect-secrets==1.5.15->llm-guard) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->bc-detect-secrets==1.5.15->llm-guard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->bc-detect-secrets==1.5.15->llm-guard) (2025.1.31)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.12.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.10.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (69.5.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=2.4.0->llm-guard) (2.1.5)
# Requirement already satisfied: requests-file>=1.4 in /opt/conda/lib/python3.11/site-packages (from tldextract->presidio-analyzer==2.2.354->llm-guard) (2.1.0)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.27.2)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (7.1.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (2.17.2)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio-analyzer==2.2.354->llm-guard) (0.1.2)
# Requirement already satisfied: guardrails-ai in /opt/conda/lib/python3.11/site-packages (0.6.2)
# Requirement already satisfied: boto3<2,>1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.36.3)
# Requirement already satisfied: coloredlogs<16.0.0,>=15.0.1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (15.0.1)
# Requirement already satisfied: diff-match-patch<20230431,>=20230430 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (20230430)
# Collecting faker<26.0.0,>=25.2.0 (from guardrails-ai)
#   Using cached Faker-25.9.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: griffe<0.37.0,>=0.36.9 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (0.36.9)
# Requirement already satisfied: guardrails-api-client<0.5.0,>=0.4.0a1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (0.4.0a1)
# Requirement already satisfied: guardrails-hub-types<0.0.5,>=0.0.4 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (0.0.4)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (4.23.0)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (0.3.40)
# Requirement already satisfied: litellm<2.0.0,>=1.37.14 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.59.3)
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (4.9.4)
# Requirement already satisfied: openai<2.0.0,>=1.30.1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.60.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.24.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (1.29.0)
# Requirement already satisfied: pip>=22 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (24.0)
# Requirement already satisfied: pydantic<3.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (2.10.5)
# Requirement already satisfied: pydash<8.0.0,>=7.0.6 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (7.0.7)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (2.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (13.9.4)
# Requirement already satisfied: rstr<4.0.0,>=3.2.2 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (3.2.2)
# Requirement already satisfied: semver<4.0.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (3.0.2)
# Requirement already satisfied: tenacity>=8.1.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (0.7.0)
# Requirement already satisfied: typer<0.13,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from typer[all]<0.13,>=0.9.0->guardrails-ai) (0.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-ai) (4.12.2)
# Requirement already satisfied: botocore<1.37.0,>=1.36.3 in /opt/conda/lib/python3.11/site-packages (from boto3<2,>1->guardrails-ai) (1.36.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3<2,>1->guardrails-ai) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.11/site-packages (from boto3<2,>1->guardrails-ai) (0.11.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.11/site-packages (from coloredlogs<16.0.0,>=15.0.1->guardrails-ai) (10.0)
# Requirement already satisfied: colorama>=0.4 in /opt/conda/lib/python3.11/site-packages (from griffe<0.37.0,>=0.36.9->guardrails-ai) (0.4.6)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from guardrails-api-client<0.5.0,>=0.4.0a1->guardrails-ai) (69.5.1)
# Requirement already satisfied: urllib3<2.1.0,>=1.25.3 in /opt/conda/lib/python3.11/site-packages (from guardrails-api-client<0.5.0,>=0.4.0a1->guardrails-ai) (2.0.7)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (0.18.0)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (1.5.1)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (3.7)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (2.4)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (0.1.4)
# Requirement already satisfied: rfc3987 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (1.3.8)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (1.13)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->guardrails-ai) (0.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->guardrails-ai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->guardrails-ai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.4,>=0.1->guardrails-ai) (24.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (3.11.11)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (8.1.7)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (0.27.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (7.1.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (3.1.3)
# Requirement already satisfied: python-dotenv>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (1.0.1)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.11/site-packages (from litellm<2.0.0,>=1.37.14->guardrails-ai) (0.21.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (0.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.30.1->guardrails-ai) (4.67.1)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.66.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.69.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (5.29.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->guardrails-ai) (0.50b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0,>=2.0.0->guardrails-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0,>=2.0.0->guardrails-ai) (2.27.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.2->guardrails-ai) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->guardrails-ai) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (2.17.2)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken>=0.5.1->guardrails-ai) (2024.7.24)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from typer<0.13,>=0.9.0->typer[all]<0.13,>=0.9.0->guardrails-ai) (1.5.4)
# WARNING: typer 0.12.5 does not provide the extra 'all'
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->guardrails-ai) (1.17.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.37.14->guardrails-ai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.37.14->guardrails-ai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.37.14->guardrails-ai) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.37.14->guardrails-ai) (2.1.5)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->guardrails-ai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->guardrails-ai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->guardrails-ai) (0.23.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->guardrails-ai) (0.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.37.14->guardrails-ai) (1.18.3)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.11/site-packages (from tokenizers->litellm<2.0.0,>=1.37.14->guardrails-ai) (0.27.1)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format]<5.0.0,>=4.22.0->guardrails-ai) (2.9.0.20240316)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.37.14->guardrails-ai) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.37.14->guardrails-ai) (2024.3.1)
# Using cached Faker-25.9.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: faker
#   Attempting uninstall: faker
#     Found existing installation: Faker 26.0.0
#     Uninstalling Faker-26.0.0:
#       Successfully uninstalled Faker-26.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llm-guard 0.3.15 requires faker<28,>=26.0.0, but you have faker 25.9.2 which is incompatible.
# Successfully installed faker-25.9.2
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (0.21.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (4.49.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # Benchmark Settings

# %%
# Define datasets

datasets: dict[tuple[str, str]] = {
    "pii": ("ai4privacy/pii-masking-200k", "train"),
    "jailbreak": ("jackhhao/jailbreak-classification", "train")    
}

pii_entities = ["PERSON", "EMAIL_ADDRESS", "PHONE_NUMBER", "IP_ADDRESS", "IBAN_CODE", "CREDIT_CARD"]

max_split_size = 1000

preferred_language = "fr"

# %% [markdown]
# # Bench tools

# %% [markdown]
# ## LLMGuard

# %%
from tools.llmguard.benchmarks import bench_pii


bench_pii(*datasets['pii'], max_split_size, preferred_language, pii_entities).display_results()
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda:0
# Split train[0:1000] of size 1000 from ai4privacy/pii-masking-200k loaded !
# Running LLMGuard PII Evaluation...
# model_to_presidio_entity_mapping is missing from configuration, using default
# low_score_entity_names is missing from configuration, using default
# labels_to_ignore is missing from configuration, using default
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# ...
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity FAC is not mapped to a Presidio entity, but keeping anyway. Add to `NerModelConfiguration.labels_to_ignore` to remove.
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Entity CUSTOM doesn't have the corresponding recognizer in language : en
# Finished LLMGuard PII Evaluation!
# Evaluation Metrics for llmguard_pii
# ========================================
#
# Confusion Matrix Statistics:
# TP: 770
# FP: 29
# TN: 349
# FN: 130
#
# Performance Metrics:
# Accuracy:   0.8756
# Precision: 0.9637
# Recall:    0.8556
# F1 Score:  0.9064
#
# Error Details:
# TP Details (770 entries):
#
# [====<0>====]
#  [entity_type] - FIRSTNAME
#  [value] - Omer
#
# [====<1>====]
#  [entity_type] - FIRSTNAME
#  [value] - Kattie
#
# [====<2>====]
#  [entity_type] - IPV6
#  [value] - edaf:fd8f:e1e8:cfec:8bab:1afd:6aad:550c
#
# [====<3>====]
#  [entity_type] - EMAIL
#  [value] - Emilie_Beatty53@hotmail.com
#
# [====<4>====]
#  [entity_type] - FIRSTNAME
#  [value] - Garrick
#   ... and 765 more
#
#
# FP Details (29 entries):
#
# [====<0>====]
#  [text] - According to Kuphal - Gislason's policy, the payment for tuition fee is accepted in Indian Rupee. Please verify and proceed accordingly.
#  [sanitized] - According to [REDACTED_PERSON_17]'s policy, the payment for tuition fee is accepted in Indian Rupee. Please verify and proceed accordingly.
#  [privacy_mask] - [{'value': 'Kuphal - Gislason', 'start': 13, 'end': 30, 'label': 'COMPANYNAME'}, {'value': 'Indian Rupee', 'start': 84, 'end': 96, 'label': 'CURRENCYNAME'}]
#  [expected] - No PII
#
# [====<1>====]
#  [entity_type] - PHONE_NUMBER
#  [text] - Billing details for Dejuan Mertz from Herminiastead need an update. The changed account number is 08735629. Please handle with discretion.
#  [privacy_mask] - [{'value': 'Dejuan', 'start': 20, 'end': 26, 'label': 'FIRSTNAME'}, {'value': 'Mertz', 'start': 27, 'end': 32, 'label': 'LASTNAME'}, {'value': 'Herminiastead', 'start': 38, 'end': 51, 'label': 'CITY'}, {'value': '08735629', 'start': 98, 'end': 106, 'label': 'ACCOUNTNUMBER'}]
#  [sanitized] - Billing details for [REDACTED_PERSON_41] from Herminiastead need an update. The changed account number is [REDACTED_PHONE_NUMBER_2]. Please handle with discretion.
#
# [====<2>====]
#  [text] - Dear Male, Our next meet-up for Social Emotional Learning professionals is going to be held at [52.9662,-17.0473]. We'll cover your expenses with card 4609385579630262.
#  [sanitized] - Dear Male, Our next meet-up for Social Emotional Learning professionals is going to be held at [52.9662,-17.0473]. We'll cover your expenses with card [REDACTED_CREDIT_CARD_2].
#  [privacy_mask] - [{'value': 'Male', 'start': 5, 'end': 9, 'label': 'SEX'}, {'value': '[52.9662,-17.0473]', 'start': 95, 'end': 113, 'label': 'NEARBYGPSCOORDINATE'}, {'value': '4609385579630262', 'start': 151, 'end': 167, 'label': 'MASKEDNUMBER'}]
#  [expected] - No PII
#
# [====<3>====]
#  [entity_type] - PHONE_NUMBER
#  [text] - Nurse Gray from suite Apt. 279 is handling the case. Her direct phone number is +234 693-143.6710, you may consult her for further details.
#  [privacy_mask] - [{'value': 'Gray', 'start': 6, 'end': 10, 'label': 'MIDDLENAME'}, {'value': 'Apt. 279', 'start': 22, 'end': 30, 'label': 'SECONDARYADDRESS'}, {'value': '+234 693-143.6710', 'start': 80, 'end': 97, 'label': 'PHONENUMBER'}]
#  [sanitized] - Nurse [REDACTED_PERSON_60] from suite Apt. 279 is handling the case. Her direct phone number is +234 [REDACTED_PHONE_NUMBER_4], you may consult her for further details.
#
# [====<4>====]
#  [text] - To the Manager at Hammes, Simonis and Ruecker, we are in need of a strategist like you. Could you kindly give us a helping hand, to expand our literacy programs in Maryland?
#  [sanitized] - To the Manager at Hammes, [REDACTED_PERSON_70] and [REDACTED_PERSON_71], we are in need of a strategist like you. Could you kindly give us a helping hand, to expand our literacy programs in Maryland?
#  [privacy_mask] - [{'value': 'Manager', 'start': 7, 'end': 14, 'label': 'JOBTYPE'}, {'value': 'Hammes, Simonis and Ruecker', 'start': 18, 'end': 45, 'label': 'COMPANYNAME'}, {'value': 'Maryland', 'start': 164, 'end': 172, 'label': 'STATE'}]
#  [expected] - No PII
#   ... and 24 more
#
#
# TN Details (0 entries):
# FN Details (130 entries):
#
# [====<0>====]
#  [entity_type] - PHONEIMEI
#  [privacy_mask] - [{'value': '06-184755-866851-3', 'start': 57, 'end': 75, 'label': 'PHONEIMEI'}, {'value': 'Optimization', 'start': 138, 'end': 150, 'label': 'JOBAREA'}]
#  [value] - 06-184755-866851-3
#  [text] - A student's assessment was found on device bearing IMEI: 06-184755-866851-3. The document falls under the various topics discussed in our Optimization curriculum. Can you please collect it?
#  [sanitized] - A student's assessment was found on device bearing IMEI: 06-184755-866851-3. The document falls under the various topics discussed in our Optimization curriculum. Can you please collect it?
#
# [====<1>====]
#  [entity_type] - FIRSTNAME
#  [privacy_mask] - [{'value': 'Carleton', 'start': 0, 'end': 8, 'label': 'FIRSTNAME'}, {'value': '[-38.9302,113.5422]', 'start': 69, 'end': 88, 'label': 'NEARBYGPSCOORDINATE'}, {'value': 'yZqd7gHyZq91', 'start': 134, 'end': 146, 'label': 'PASSWORD'}]
#  [value] - Carleton
#  [text] - Carleton, the new interactive educational tools are set to arrive at [-38.9302,113.5422]. Your password for accessing online content: yZqd7gHyZq91.
#  [sanitized] - Carleton, the new interactive educational tools are set to arrive at [-38.9302,113.5422]. Your password for accessing online content: yZqd7gHyZq91.
#
# [====<2>====]
#  [entity_type] - PHONEIMEI
#  [privacy_mask] - [{'value': 'Ms.', 'start': 0, 'end': 3, 'label': 'PREFIX'}, {'value': 'North', 'start': 3, 'end': 8, 'label': 'MIDDLENAME'}, {'value': 'Essex', 'start': 24, 'end': 29, 'label': 'COUNTY'}, {'value': '10:02 AM', 'start': 79, 'end': 87, 'label': 'TIME'}, {'value': '04-558619-832604-8', 'start': 107, 'end': 125, 'label': 'PHONEIMEI'}]
#  [value] - 04-558619-832604-8
#  [text] - Ms.North, our office in Essex confirmed your visit with health psychologist at 10:02 AM. Your file with ID 04-558619-832604-8 is updated.
#  [sanitized] - Ms.[REDACTED_PERSON_7], our office in Essex confirmed your visit with health psychologist at 10:02 AM. Your file with ID 04-558619-832604-8 is updated.
#
# [====<3>====]
#  [entity_type] - CREDITCARDNUMBER
#  [privacy_mask] - [{'value': 'discover', 'start': 98, 'end': 106, 'label': 'CREDITCARDISSUER'}, {'value': '2948447876023997', 'start': 128, 'end': 144, 'label': 'CREDITCARDNUMBER'}]
#  [value] - 2948447876023997
#  [text] - To facilitate your payments for treatment, the hospital accepts transactions from cards issued by discover bearing numbers like 2948447876023997.
#  [sanitized] - To facilitate your payments for treatment, the hospital accepts transactions from cards issued by discover bearing numbers like 2948447876023997.
#
# [====<4>====]
#  [entity_type] - CREDITCARDNUMBER
#  [privacy_mask] - [{'value': '6381973478101820', 'start': 71, 'end': 87, 'label': 'CREDITCARDNUMBER'}, {'value': '215.114.180.213', 'start': 137, 'end': 152, 'label': 'IPV4'}, {'value': 'Investor Program Supervisor', 'start': 161, 'end': 188, 'label': 'JOBTITLE'}]
#  [value] - 6381973478101820
#  [text] - I've noticed some unusual activities related to the credit card number 6381973478101820. The transactions are coming from the IP address 215.114.180.213. As our Investor Program Supervisor, could you please investigate?
#  [sanitized] - I've noticed some unusual activities related to the credit card number 6381973478101820. The transactions are coming from the IP address [REDACTED_IP_ADDRESS_4]. As our Investor Program Supervisor, could you please investigate?
#   ... and 125 more
#
#
#
# Evaluated prompts: 1000
#
# Evaluation Duration: 0:00:13.296381
#
# Mean processing time: 0:00:00.013296
